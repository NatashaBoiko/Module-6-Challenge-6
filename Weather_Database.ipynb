# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180,high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?lat=units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=units=Imperial&APPID=b88467ab6d1d312c980796fd4d24365e

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        print(lat, lng, max_temp, humidity, clouds, wind, country)     
            
        # Append the city information into the city_data list
        city_data.append(city)
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.88, 'feels_like': 288.31, 'temp_min': 288.88, 'temp_max': 288.88, 'pressure': 1011, 'humidity': 69, 'sea_level': 1011, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 2.52, 'deg': 13, 'gust': 3.1}, 'clouds': {'all': 82}, 'dt': 1674234047, 'sys': {'country': 'AR', 'sunrise': 1674203482, 'sunset': 1674262593}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# -54.8 -68.3 288.88 69 82 2.52 AR
# Processing Record 2 of Set 1 | gualeguaychu
# {'coord': {'lon': -58.5172, 'lat': -33.0094}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 313.69, 'feels_like': 313.3, 'temp_min': 313.69, 'temp_max': 313.69, 'pressure': 1005, 'humidity': 20, 'sea_level': 1005, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 4.13, 'deg': 35, 'gust': 3.13}, 'clouds': {'all': 7}, 'dt': 1674234000, 'sys': {'country': 'AR', 'sunrise': 1674205518, 'sunset': 1674255861}, 'timezone': -10800, 'id': 3433658, 'name': 'Gualeguaychú', 'cod': 200}
# -33.0094 -58.5172 313.69 20 7 4.13 AR
# Processing Record 3 of Set 1 | iqaluit
# {'coord': {'lon': -68.5145, 'lat': 63.7506}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 249.41, 'feels_like': 242.91, 'temp_min': 249.41, 'temp_max': 249.41, 'pressure': 1010, 'humidity': 98, 'sea_level': 1010, 'grnd_level': 1003}, 'visibility': 7851, 'wind': {'speed': 2.06, 'deg': 359, 'gust': 2}, 'clouds': {'all': 85}, 'dt': 1674234048, 'sys': {'country': 'CA', 'sunrise': 1674222326, 'sunset': 1674243853}, 'timezone': -18000, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# 63.7506 -68.5145 249.41 98 85 2.06 CA
# Processing Record 4 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 295.05, 'feels_like': 294.68, 'temp_min': 295.05, 'temp_max': 295.05, 'pressure': 1011, 'humidity': 53, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.44, 'deg': 105, 'gust': 12.85}, 'clouds': {'all': 13}, 'dt': 1674234049, 'sys': {'country': 'AU', 'sunrise': 1674250139, 'sunset': 1674300610}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# -33.65 115.3333 295.05 53 13 6.44 AU
# Processing Record 5 of Set 1 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 236.45, 'feels_like': 229.45, 'temp_min': 236.45, 'temp_max': 236.45, 'pressure': 1040, 'humidity': 100, 'sea_level': 1040, 'grnd_level': 1036}, 'visibility': 9324, 'wind': {'speed': 2.58, 'deg': 229, 'gust': 2.61}, 'clouds': {'all': 100}, 'dt': 1674234049, 'sys': {'country': 'RU', 'sunrise': 1674265839, 'sunset': 1674269267}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# 70.6333 147.9167 236.45 100 100 2.58 RU
# Processing Record 6 of Set 1 | airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 288.06, 'feels_like': 287.96, 'temp_min': 288.06, 'temp_max': 288.06, 'pressure': 1010, 'humidity': 90, 'sea_level': 1010, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 0.16, 'deg': 295, 'gust': 1.06}, 'rain': {'1h': 0.38}, 'clouds': {'all': 100}, 'dt': 1674233755, 'sys': {'country': 'TL', 'sunrise': 1674250352, 'sunset': 1674295560}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# -8.9266 125.4092 288.06 90 100 0.16 TL
# Processing Record 7 of Set 1 | cidreira
# {'coord': {'lon': -50.2056, 'lat': -30.1811}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 299.03, 'feels_like': 299.63, 'temp_min': 299.03, 'temp_max': 299.03, 'pressure': 1011, 'humidity': 75, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 5.72, 'deg': 75, 'gust': 6.77}, 'clouds': {'all': 22}, 'dt': 1674234050, 'sys': {'country': 'BR', 'sunrise': 1674203884, 'sunset': 1674253504}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# -30.1811 -50.2056 299.03 75 22 5.72 BR
# Processing Record 8 of Set 1 | mehamn
# {'coord': {'lon': 27.8492, 'lat': 71.0357}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 275.12, 'feels_like': 268.96, 'temp_min': 271.1, 'temp_max': 275.12, 'pressure': 1002, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 9.26, 'deg': 230}, 'rain': {'1h': 0.44}, 'clouds': {'all': 75}, 'dt': 1674234051, 'sys': {'type': 1, 'id': 1633, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 778707, 'name': 'Mehamn', 'cod': 200}
# 71.0357 27.8492 275.12 75 75 9.26 NO
# Processing Record 9 of Set 1 | raudeberg
# {'coord': {'lon': 5.1352, 'lat': 61.9875}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 274.74, 'feels_like': 270.22, 'temp_min': 273.52, 'temp_max': 274.74, 'pressure': 1022, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 5, 'deg': 145, 'gust': 5.37}, 'clouds': {'all': 66}, 'dt': 1674234052, 'sys': {'type': 2, 'id': 2003008, 'country': 'NO', 'sunrise': 1674203691, 'sunset': 1674227128}, 'timezone': 3600, 'id': 3146487, 'name': 'Raudeberg', 'cod': 200}
# 61.9875 5.1352 274.74 72 66 5 NO
# Processing Record 10 of Set 1 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.72, 'feels_like': 289.47, 'temp_min': 289.72, 'temp_max': 289.72, 'pressure': 1017, 'humidity': 78, 'sea_level': 1017, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 7.8, 'deg': 66, 'gust': 12.09}, 'clouds': {'all': 0}, 'dt': 1674234052, 'sys': {'country': 'AU', 'sunrise': 1674248533, 'sunset': 1674299064}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# -33.8667 121.9 289.72 78 0 7.8 AU
# Processing Record 11 of Set 1 | liverpool
# {'coord': {'lon': -2.9779, 'lat': 53.4106}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 277.67, 'feels_like': 275.9, 'temp_min': 275.62, 'temp_max': 279.12, 'pressure': 1021, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 20}, 'dt': 1674233924, 'sys': {'type': 2, 'id': 2008599, 'country': 'GB', 'sunrise': 1674202474, 'sunset': 1674232240}, 'timezone': 0, 'id': 2644210, 'name': 'Liverpool', 'cod': 200}
# 53.4106 -2.9779 279.12 80 20 2.06 GB
# Processing Record 12 of Set 1 | alibag
# {'coord': {'lon': 72.8792, 'lat': 18.6411}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 297.19, 'feels_like': 297.4, 'temp_min': 297.19, 'temp_max': 297.19, 'pressure': 1014, 'humidity': 67, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.25, 'deg': 0, 'gust': 2.42}, 'clouds': {'all': 87}, 'dt': 1674234053, 'sys': {'type': 1, 'id': 9052, 'country': 'IN', 'sunrise': 1674179036, 'sunset': 1674219260}, 'timezone': 19800, 'id': 1279027, 'name': 'Alibag', 'cod': 200}
# 18.6411 72.8792 297.19 67 87 2.25 IN
# Processing Record 13 of Set 1 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 286.4, 'feels_like': 286.13, 'temp_min': 285.07, 'temp_max': 286.63, 'pressure': 1013, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 320}, 'clouds': {'all': 96}, 'dt': 1674233827, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1674241029, 'sunset': 1674294360}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# -42.8794 147.3294 286.63 90 96 2.57 AU
# Processing Record 14 of Set 1 | labuhan
# {'coord': {'lon': 112.2051, 'lat': -6.8844}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 297.98, 'feels_like': 298.84, 'temp_min': 297.98, 'temp_max': 297.98, 'pressure': 1009, 'humidity': 89, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.92, 'deg': 203, 'gust': 6.6}, 'clouds': {'all': 100}, 'dt': 1674234054, 'sys': {'country': 'ID', 'sunrise': 1674253706, 'sunset': 1674298545}, 'timezone': 25200, 'id': 8079926, 'name': 'Labuhan', 'cod': 200}
# -6.8844 112.2051 297.98 89 100 3.92 ID
# Processing Record 15 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 298.46, 'feels_like': 298.82, 'temp_min': 298.46, 'temp_max': 298.46, 'pressure': 1016, 'humidity': 68, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 2.58, 'deg': 29, 'gust': 2.61}, 'rain': {'1h': 0.17}, 'clouds': {'all': 97}, 'dt': 1674234055, 'sys': {'country': 'PF', 'sunrise': 1674225050, 'sunset': 1674273034}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# -23.1203 -134.9692 298.46 68 97 2.58 PF
# Processing Record 16 of Set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 270.06, 'feels_like': 267.8, 'temp_min': 270.06, 'temp_max': 270.06, 'pressure': 995, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1674234055, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# 78.2186 15.6401 270.06 93 75 1.54 SJ
# Processing Record 17 of Set 1 | barentsburg
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 18 of Set 1 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 264.24, 'feels_like': 259.05, 'temp_min': 264.24, 'temp_max': 264.24, 'pressure': 982, 'humidity': 95, 'sea_level': 982, 'grnd_level': 977}, 'visibility': 2675, 'wind': {'speed': 2.91, 'deg': 267, 'gust': 4.28}, 'clouds': {'all': 100}, 'dt': 1674234057, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1674216220, 'sunset': 1674235135}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# 65.6145 -37.6368 264.24 95 100 2.91 GL
# Processing Record 19 of Set 1 | cotonou
# {'coord': {'lon': 2.4183, 'lat': 6.3654}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.66, 'feels_like': 305.33, 'temp_min': 301.66, 'temp_max': 301.66, 'pressure': 1009, 'humidity': 73, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.95, 'deg': 196, 'gust': 6.7}, 'clouds': {'all': 93}, 'dt': 1674234029, 'sys': {'country': 'BJ', 'sunrise': 1674194812, 'sunset': 1674237311}, 'timezone': 3600, 'id': 2394819, 'name': 'Cotonou', 'cod': 200}
# 6.3654 2.4183 301.66 73 93 5.95 BJ
# Processing Record 20 of Set 1 | poya
# {'coord': {'lon': 165.15, 'lat': -21.35}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 297.9, 'feels_like': 298.83, 'temp_min': 297.9, 'temp_max': 297.9, 'pressure': 1003, 'humidity': 92, 'sea_level': 1003, 'grnd_level': 1002}, 'visibility': 8268, 'wind': {'speed': 4.26, 'deg': 38, 'gust': 8.37}, 'rain': {'1h': 1}, 'clouds': {'all': 100}, 'dt': 1674234057, 'sys': {'country': 'NC', 'sunrise': 1674239615, 'sunset': 1674287217}, 'timezone': 39600, 'id': 2138522, 'name': 'Poya', 'cod': 200}
# -21.35 165.15 297.9 92 100 4.26 NC
# Processing Record 21 of Set 1 | saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 276.61, 'feels_like': 274.66, 'temp_min': 276.45, 'temp_max': 276.72, 'pressure': 1020, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 190}, 'clouds': {'all': 0}, 'dt': 1674234040, 'sys': {'type': 2, 'id': 2010805, 'country': 'US', 'sunrise': 1674225893, 'sunset': 1674261924}, 'timezone': -25200, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# 37.1041 -113.5841 276.72 77 0 2.06 US
# Processing Record 22 of Set 1 | mahebourg
# {'coord': {'lon': 57.7, 'lat': -20.4081}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.29, 'feels_like': 299.05, 'temp_min': 298.29, 'temp_max': 298.29, 'pressure': 1013, 'humidity': 84, 'sea_level': 1013, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.2, 'deg': 53, 'gust': 4.46}, 'rain': {'1h': 0.33}, 'clouds': {'all': 96}, 'dt': 1674234058, 'sys': {'type': 2, 'id': 2002134, 'country': 'MU', 'sunrise': 1674179072, 'sunset': 1674226511}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# -20.4081 57.7 298.29 84 96 3.2 MU
# Processing Record 23 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 297.37, 'feels_like': 297.49, 'temp_min': 295.43, 'temp_max': 297.65, 'pressure': 1011, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 124, 'gust': 4.92}, 'clouds': {'all': 0}, 'dt': 1674234059, 'sys': {'type': 2, 'id': 2073005, 'country': 'ZA', 'sunrise': 1674186917, 'sunset': 1674237523}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# -33.9258 18.4232 297.65 63 0 2.68 ZA
# Processing Record 24 of Set 1 | samarai
# {'coord': {'lon': 150.6667, 'lat': -10.6167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.37, 'feels_like': 303.28, 'temp_min': 300.37, 'temp_max': 300.37, 'pressure': 1005, 'humidity': 79, 'sea_level': 1005, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 1.47, 'deg': 288, 'gust': 1.4}, 'clouds': {'all': 100}, 'dt': 1674234060, 'sys': {'country': 'PG', 'sunrise': 1674244135, 'sunset': 1674289651}, 'timezone': 36000, 'id': 2132606, 'name': 'Samarai', 'cod': 200}
# -10.6167 150.6667 300.37 79 100 1.47 PG
# Processing Record 25 of Set 1 | talnakh
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 238.61, 'feels_like': 231.61, 'temp_min': 238.61, 'temp_max': 238.61, 'pressure': 1054, 'humidity': 88, 'sea_level': 1054, 'grnd_level': 1044}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 124, 'gust': 2.44}, 'clouds': {'all': 7}, 'dt': 1674234060, 'sys': {'country': 'RU', 'sunrise': 1674276663, 'sunset': 1674287018}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# 69.4865 88.3972 238.61 88 7 2.68 RU
# Processing Record 26 of Set 1 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 296.52, 'feels_like': 296.84, 'temp_min': 296.52, 'temp_max': 296.52, 'pressure': 1011, 'humidity': 74, 'sea_level': 1011, 'grnd_level': 902}, 'visibility': 10000, 'wind': {'speed': 0.61, 'deg': 334, 'gust': 0.69}, 'rain': {'1h': 1.06}, 'clouds': {'all': 22}, 'dt': 1674234061, 'sys': {'country': 'BR', 'sunrise': 1674204468, 'sunset': 1674252828}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# -24.7911 -50.0119 296.52 74 22 0.61 BR
# Processing Record 27 of Set 1 | kavaratti
# {'coord': {'lon': 72.642, 'lat': 10.5669}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 299.98, 'feels_like': 301.29, 'temp_min': 299.98, 'temp_max': 299.98, 'pressure': 1014, 'humidity': 64, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 1.44, 'deg': 327, 'gust': 1.66}, 'clouds': {'all': 55}, 'dt': 1674234062, 'sys': {'country': 'IN', 'sunrise': 1674178334, 'sunset': 1674220075}, 'timezone': 19800, 'id': 1267390, 'name': 'Kavaratti', 'cod': 200}
# 10.5669 72.642 299.98 64 55 1.44 IN
# Processing Record 28 of Set 1 | port elizabeth
# {'coord': {'lon': 25.5701, 'lat': -33.918}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 297.21, 'feels_like': 297.86, 'temp_min': 297.21, 'temp_max': 297.21, 'pressure': 1013, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 116, 'gust': 4.02}, 'clouds': {'all': 36}, 'dt': 1674234062, 'sys': {'type': 2, 'id': 2072678, 'country': 'ZA', 'sunrise': 1674185202, 'sunset': 1674235807}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}
# -33.918 25.5701 297.21 84 36 2.24 ZA
# Processing Record 29 of Set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 296.52, 'feels_like': 296.51, 'temp_min': 296.52, 'temp_max': 296.52, 'pressure': 1012, 'humidity': 61, 'sea_level': 1012, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 4.17, 'deg': 174, 'gust': 3.45}, 'clouds': {'all': 20}, 'dt': 1674234063, 'sys': {'country': 'ZA', 'sunrise': 1674186445, 'sunset': 1674237218}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# -34.5322 20.0403 296.52 61 20 4.17 ZA
# Processing Record 30 of Set 1 | katsuura
# {'coord': {'lon': 140.3, 'lat': 35.1333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 280.59, 'feels_like': 276.19, 'temp_min': 280.59, 'temp_max': 280.59, 'pressure': 1015, 'humidity': 47, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 9.1, 'deg': 4, 'gust': 11.67}, 'clouds': {'all': 7}, 'dt': 1674234064, 'sys': {'country': 'JP', 'sunrise': 1674251086, 'sunset': 1674287677}, 'timezone': 32400, 'id': 2112309, 'name': 'Katsuura', 'cod': 200}
# 35.1333 140.3 280.59 47 7 9.1 JP
# Processing Record 31 of Set 1 | broome
# {'coord': {'lon': -75.833, 'lat': 42.2506}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 276.15, 'feels_like': 272.27, 'temp_min': 274.58, 'temp_max': 277.51, 'pressure': 983, 'humidity': 88}, 'visibility': 23, 'wind': {'speed': 4.47, 'deg': 246, 'gust': 6.71}, 'clouds': {'all': 100}, 'dt': 1674234064, 'sys': {'type': 2, 'id': 2036074, 'country': 'US', 'sunrise': 1674217614, 'sunset': 1674252079}, 'timezone': -18000, 'id': 5110365, 'name': 'Broome', 'cod': 200}
# 42.2506 -75.833 277.51 88 100 4.47 US
# Processing Record 32 of Set 1 | marawi
# {'coord': {'lon': 124.2928, 'lat': 7.9986}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 292.5, 'feels_like': 292.95, 'temp_min': 292.5, 'temp_max': 292.5, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 930}, 'visibility': 10000, 'wind': {'speed': 0.84, 'deg': 146, 'gust': 1.15}, 'clouds': {'all': 56}, 'dt': 1674234065, 'sys': {'country': 'PH', 'sunrise': 1674252115, 'sunset': 1674294333}, 'timezone': 28800, 'id': 1701054, 'name': 'Marawi', 'cod': 200}
# 7.9986 124.2928 292.5 94 56 0.84 PH
# Processing Record 33 of Set 1 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 237.5, 'feels_like': 230.5, 'temp_min': 237.5, 'temp_max': 237.5, 'pressure': 1009, 'humidity': 59, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 4.07, 'deg': 53, 'gust': 4.52}, 'clouds': {'all': 0}, 'dt': 1674234066, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# 77.484 -69.3632 237.5 59 0 4.07 GL
# Processing Record 34 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.42, 'feels_like': 303.07, 'temp_min': 300.42, 'temp_max': 300.42, 'pressure': 1007, 'humidity': 76, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 8.49, 'deg': 107, 'gust': 9.35}, 'clouds': {'all': 73}, 'dt': 1674234067, 'sys': {'country': 'KI', 'sunrise': 1674240039, 'sunset': 1674283125}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# 3.0707 172.7902 300.42 76 73 8.49 KI
# Processing Record 35 of Set 1 | mrirt
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 36 of Set 1 | ponta do sol
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 291.86, 'feels_like': 291.41, 'temp_min': 290.5, 'temp_max': 292.43, 'pressure': 1026, 'humidity': 62, 'sea_level': 1026, 'grnd_level': 1026}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 55, 'gust': 3.16}, 'clouds': {'all': 67}, 'dt': 1674234068, 'sys': {'type': 2, 'id': 2008291, 'country': 'PT', 'sunrise': 1674202159, 'sunset': 1674239336}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# 32.6667 -17.1 292.43 62 67 2.39 PT
# Processing Record 37 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 274.84, 'feels_like': 274.84, 'temp_min': 273.34, 'temp_max': 276.84, 'pressure': 1000, 'humidity': 94}, 'visibility': 1579, 'wind': {'speed': 0.45, 'deg': 288, 'gust': 1.79}, 'snow': {'1h': 1.89}, 'clouds': {'all': 100}, 'dt': 1674233917, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1674217224, 'sunset': 1674251573}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# 42.6001 -73.9662 276.84 94 100 0.45 US
# Processing Record 38 of Set 1 | vao
# {'coord': {'lon': 167.4833, 'lat': -22.6667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.47, 'feels_like': 298.91, 'temp_min': 298.47, 'temp_max': 298.47, 'pressure': 1006, 'humidity': 71, 'sea_level': 1006, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 8.97, 'deg': 60, 'gust': 9.08}, 'clouds': {'all': 100}, 'dt': 1674234068, 'sys': {'country': 'NC', 'sunrise': 1674238917, 'sunset': 1674286795}, 'timezone': 39600, 'id': 2137773, 'name': 'Vao', 'cod': 200}
# -22.6667 167.4833 298.47 71 100 8.97 NC
# Processing Record 39 of Set 1 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.76, 'feels_like': 303.67, 'temp_min': 300.76, 'temp_max': 300.76, 'pressure': 1005, 'humidity': 75, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 2.58, 'deg': 311, 'gust': 2.77}, 'clouds': {'all': 100}, 'dt': 1674234069, 'sys': {'country': 'PG', 'sunrise': 1674244824, 'sunset': 1674288900}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# -2.5744 150.7967 300.76 75 100 2.58 PG
# Processing Record 40 of Set 1 | xunchang
# {'coord': {'lon': 104.715, 'lat': 28.4543}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 278.67, 'feels_like': 278.67, 'temp_min': 278.67, 'temp_max': 278.67, 'pressure': 1024, 'humidity': 70, 'sea_level': 1024, 'grnd_level': 965}, 'visibility': 10000, 'wind': {'speed': 0.44, 'deg': 218, 'gust': 0.5}, 'clouds': {'all': 30}, 'dt': 1674234070, 'sys': {'country': 'CN', 'sunrise': 1674258813, 'sunset': 1674297034}, 'timezone': 28800, 'id': 1787901, 'name': 'Xunchang', 'cod': 200}
# 28.4543 104.715 278.67 70 30 0.44 CN
# Processing Record 41 of Set 1 | maneadero
# {'coord': {'lon': -116.5667, 'lat': 31.7167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 284.87, 'feels_like': 284.13, 'temp_min': 284.87, 'temp_max': 284.87, 'pressure': 1022, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 157, 'gust': 3.58}, 'clouds': {'all': 75}, 'dt': 1674234047, 'sys': {'type': 2, 'id': 2001695, 'country': 'MX', 'sunrise': 1674225909, 'sunset': 1674263340}, 'timezone': -28800, 'id': 3996737, 'name': 'Rodolfo Sánchez Taboada', 'cod': 200}
# 31.7167 -116.5667 284.87 78 75 2.68 MX
# Processing Record 42 of Set 1 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 250.68, 'feels_like': 250.68, 'temp_min': 250.68, 'temp_max': 250.68, 'pressure': 1004, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 180}, 'clouds': {'all': 64}, 'dt': 1674234072, 'sys': {'type': 2, 'id': 47671, 'country': 'CA', 'sunrise': 1674232570, 'sunset': 1674255616}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# 62.456 -114.3525 250.68 83 64 0.89 CA
# Processing Record 43 of Set 1 | batagay
# {'coord': {'lon': 134.6333, 'lat': 67.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 230.63, 'feels_like': 230.63, 'temp_min': 230.63, 'temp_max': 230.63, 'pressure': 1050, 'humidity': 97, 'sea_level': 1050, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 221, 'gust': 0.57}, 'clouds': {'all': 100}, 'dt': 1674234073, 'sys': {'country': 'RU', 'sunrise': 1674263019, 'sunset': 1674278464}, 'timezone': 36000, 'id': 2027044, 'name': 'Batagay', 'cod': 200}
# 67.6333 134.6333 230.63 97 100 0.45 RU
# Processing Record 44 of Set 1 | mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 45 of Set 1 | obsharovka
# {'coord': {'lon': 48.8531, 'lat': 53.125}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 255.15, 'feels_like': 249.61, 'temp_min': 255.15, 'temp_max': 255.15, 'pressure': 1044, 'humidity': 97, 'sea_level': 1044, 'grnd_level': 1038}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 123, 'gust': 2.31}, 'clouds': {'all': 22}, 'dt': 1674234074, 'sys': {'country': 'RU', 'sunrise': 1674189968, 'sunset': 1674219863}, 'timezone': 14400, 'id': 516342, 'name': 'Obsharovka', 'cod': 200}
# 53.125 48.8531 255.15 97 22 2.06 RU
# Processing Record 46 of Set 1 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 299.01, 'feels_like': 299.98, 'temp_min': 299.01, 'temp_max': 299.01, 'pressure': 1013, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 3.13, 'deg': 127, 'gust': 4.47}, 'clouds': {'all': 38}, 'dt': 1674234075, 'sys': {'type': 2, 'id': 2005652, 'country': 'EC', 'sunrise': 1674216454, 'sunset': 1674260209}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# -0.7393 -90.3518 299.01 89 38 3.13 EC
# Processing Record 47 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 284.98, 'feels_like': 284.12, 'temp_min': 284.98, 'temp_max': 284.98, 'pressure': 1011, 'humidity': 73, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.91, 'deg': 227, 'gust': 8.53}, 'clouds': {'all': 74}, 'dt': 1674234076, 'sys': {'country': 'NZ', 'sunrise': 1674235261, 'sunset': 1674290043}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# -46.6 168.3333 284.98 73 74 5.91 NZ
# Processing Record 48 of Set 1 | leningradskiy
# {'coord': {'lon': 178.4167, 'lat': 69.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 240.57, 'feels_like': 233.57, 'temp_min': 240.57, 'temp_max': 240.57, 'pressure': 1021, 'humidity': 93, 'sea_level': 1021, 'grnd_level': 1021}, 'visibility': 4627, 'wind': {'speed': 6.4, 'deg': 298, 'gust': 9.9}, 'clouds': {'all': 100}, 'dt': 1674234077, 'sys': {'country': 'RU', 'sunrise': 1674254971, 'sunset': 1674265493}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# 69.3833 178.4167 240.57 93 100 6.4 RU
# Processing Record 49 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.93, 'feels_like': 297.32, 'temp_min': 296.93, 'temp_max': 296.93, 'pressure': 1012, 'humidity': 75, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.32, 'deg': 198, 'gust': 2.41}, 'clouds': {'all': 0}, 'dt': 1674234077, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1674186655, 'sunset': 1674237396}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# -34.4187 19.2345 296.93 75 0 2.32 ZA
# Processing Record 50 of Set 1 | dingle
# {'coord': {'lon': 122.6711, 'lat': 10.9995}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.58, 'feels_like': 297.43, 'temp_min': 296.58, 'temp_max': 296.58, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 3.85, 'deg': 13, 'gust': 6.98}, 'clouds': {'all': 83}, 'dt': 1674234078, 'sys': {'country': 'PH', 'sunrise': 1674252773, 'sunset': 1674294454}, 'timezone': 28800, 'id': 1714733, 'name': 'Dingle', 'cod': 200}
# 10.9995 122.6711 296.58 94 83 3.85 PH
# Processing Record 1 of Set 2 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 244.23, 'feels_like': 237.23, 'temp_min': 244.23, 'temp_max': 244.23, 'pressure': 1007, 'humidity': 88, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 3256, 'wind': {'speed': 2.68, 'deg': 172, 'gust': 4.12}, 'clouds': {'all': 100}, 'dt': 1674234139, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# 72.7868 -56.1549 244.23 88 100 2.68 GL
# Processing Record 2 of Set 2 | guerrero negro
# {'coord': {'lon': -114.0611, 'lat': 27.9769}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 288.94, 'feels_like': 288.22, 'temp_min': 288.94, 'temp_max': 288.94, 'pressure': 1022, 'humidity': 63, 'sea_level': 1022, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 8.62, 'deg': 329, 'gust': 9.97}, 'clouds': {'all': 7}, 'dt': 1674234045, 'sys': {'country': 'MX', 'sunrise': 1674224871, 'sunset': 1674263175}, 'timezone': -25200, 'id': 4021858, 'name': 'Guerrero Negro', 'cod': 200}
# 27.9769 -114.0611 288.94 63 7 8.62 MX
# Processing Record 3 of Set 2 | aripuana
# {'coord': {'lon': -60.6333, 'lat': -9.1667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 303.53, 'feels_like': 305.89, 'temp_min': 303.53, 'temp_max': 303.53, 'pressure': 1012, 'humidity': 56, 'sea_level': 1012, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 1.66, 'deg': 340, 'gust': 2.52}, 'clouds': {'all': 79}, 'dt': 1674234140, 'sys': {'country': 'BR', 'sunrise': 1674208567, 'sunset': 1674253828}, 'timezone': -14400, 'id': 3665202, 'name': 'Aripuanã', 'cod': 200}
# -9.1667 -60.6333 303.53 56 79 1.66 BR
# Processing Record 4 of Set 2 | stoyba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 285.99, 'feels_like': 285.05, 'temp_min': 285.99, 'temp_max': 285.99, 'pressure': 1012, 'humidity': 66, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.21, 'deg': 78, 'gust': 2.32}, 'clouds': {'all': 100}, 'dt': 1674234141, 'sys': {'type': 2, 'id': 47745, 'country': 'CL', 'sunrise': 1674204624, 'sunset': 1674262708}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# -53.15 -70.9167 285.99 66 100 1.21 CL
# Processing Record 6 of Set 2 | cordele
# {'coord': {'lon': -83.7824, 'lat': 31.9635}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 287.34, 'feels_like': 285.89, 'temp_min': 287.14, 'temp_max': 289.51, 'pressure': 1022, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1674234142, 'sys': {'type': 1, 'id': 3631, 'country': 'US', 'sunrise': 1674218072, 'sunset': 1674255437}, 'timezone': -18000, 'id': 4189423, 'name': 'Cordele', 'cod': 200}
# 31.9635 -83.7824 289.51 41 0 2.06 US
# Processing Record 7 of Set 2 | amderma
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 2 | sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 9 of Set 2 | vettavalam
# {'coord': {'lon': 79.25, 'lat': 12.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 293.56, 'feels_like': 293.88, 'temp_min': 293.56, 'temp_max': 293.56, 'pressure': 1015, 'humidity': 85, 'sea_level': 1015, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 34, 'gust': 2.38}, 'clouds': {'all': 85}, 'dt': 1674234143, 'sys': {'country': 'IN', 'sunrise': 1674176888, 'sunset': 1674218348}, 'timezone': 19800, 'id': 1253217, 'name': 'Vettavalam', 'cod': 200}
# 12.1 79.25 293.56 85 85 2.24 IN
# Processing Record 10 of Set 2 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 274.88, 'feels_like': 268.81, 'temp_min': 274.88, 'temp_max': 274.88, 'pressure': 989, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 8.75, 'deg': 290, 'gust': 11.32}, 'rain': {'1h': 0.25}, 'clouds': {'all': 100}, 'dt': 1674234075, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1674239665, 'sunset': 1674266791}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# 57.79 -152.4072 274.88 87 100 8.75 US
# Processing Record 11 of Set 2 | saint-philippe
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.92, 'feels_like': 305.86, 'temp_min': 297.1, 'temp_max': 300.92, 'pressure': 1013, 'humidity': 88, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 5.62, 'deg': 53, 'gust': 6.69}, 'clouds': {'all': 100}, 'dt': 1674233984, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1674179437, 'sunset': 1674227073}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# -21.3585 55.7679 300.92 88 100 5.62 RE
# Processing Record 12 of Set 2 | labutta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 13 of Set 2 | ahipara
# {'coord': {'lon': 173.1667, 'lat': -35.1667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 290.75, 'feels_like': 290.94, 'temp_min': 290.75, 'temp_max': 290.75, 'pressure': 1011, 'humidity': 91, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.56, 'deg': 207, 'gust': 3.58}, 'clouds': {'all': 68}, 'dt': 1674234145, 'sys': {'country': 'NZ', 'sunrise': 1674236042, 'sunset': 1674286942}, 'timezone': 46800, 'id': 2194098, 'name': 'Ahipara', 'cod': 200}
# -35.1667 173.1667 290.75 91 68 2.56 NZ
# Processing Record 14 of Set 2 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.41, 'feels_like': 281.68, 'temp_min': 282.41, 'temp_max': 282.41, 'pressure': 1011, 'humidity': 89, 'sea_level': 1011, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 1.77, 'deg': 274, 'gust': 7.78}, 'clouds': {'all': 67}, 'dt': 1674234145, 'sys': {'country': 'NZ', 'sunrise': 1674235218, 'sunset': 1674289831}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# -46.1927 168.8643 282.41 89 67 1.77 NZ
# Processing Record 15 of Set 2 | bria
# {'coord': {'lon': 21.9863, 'lat': 6.5423}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 302.91, 'feels_like': 301.11, 'temp_min': 302.91, 'temp_max': 302.91, 'pressure': 1006, 'humidity': 16, 'sea_level': 1006, 'grnd_level': 943}, 'visibility': 10000, 'wind': {'speed': 0.95, 'deg': 333, 'gust': 1.06}, 'clouds': {'all': 96}, 'dt': 1674234146, 'sys': {'country': 'CF', 'sunrise': 1674190131, 'sunset': 1674232598}, 'timezone': 3600, 'id': 239899, 'name': 'Bria', 'cod': 200}
# 6.5423 21.9863 302.91 16 96 0.95 CF
# Processing Record 16 of Set 2 | abu dhabi
# {'coord': {'lon': 54.3667, 'lat': 24.4667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 293.34, 'feels_like': 293.09, 'temp_min': 292.57, 'temp_max': 294.21, 'pressure': 1019, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1674233941, 'sys': {'type': 2, 'id': 2043159, 'country': 'AE', 'sunrise': 1674184071, 'sunset': 1674223113}, 'timezone': 14400, 'id': 292968, 'name': 'Abu Dhabi', 'cod': 200}
# 24.4667 54.3667 294.21 64 0 2.57 AE
# Processing Record 17 of Set 2 | ustrzyki dolne
# {'coord': {'lon': 22.5938, 'lat': 49.4304}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 271, 'feels_like': 266.15, 'temp_min': 271, 'temp_max': 271, 'pressure': 1011, 'humidity': 100, 'sea_level': 1011, 'grnd_level': 954}, 'visibility': 67, 'wind': {'speed': 4.1, 'deg': 35, 'gust': 9.95}, 'snow': {'1h': 0.22}, 'clouds': {'all': 100}, 'dt': 1674234147, 'sys': {'type': 2, 'id': 2034295, 'country': 'PL', 'sunrise': 1674195367, 'sunset': 1674227070}, 'timezone': 3600, 'id': 756280, 'name': 'Ustrzyki Dolne', 'cod': 200}
# 49.4304 22.5938 271 100 100 4.1 PL
# Processing Record 18 of Set 2 | itoman
# {'coord': {'lon': 127.6694, 'lat': 26.1247}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 288.16, 'feels_like': 287.36, 'temp_min': 288.16, 'temp_max': 288.16, 'pressure': 1024, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 40}, 'clouds': {'all': 12}, 'dt': 1674234147, 'sys': {'type': 1, 'id': 8137, 'country': 'JP', 'sunrise': 1674253048, 'sunset': 1674291779}, 'timezone': 32400, 'id': 1861280, 'name': 'Itoman', 'cod': 200}
# 26.1247 127.6694 288.16 63 12 3.6 JP
# Processing Record 19 of Set 2 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 232.66, 'feels_like': 225.66, 'temp_min': 232.66, 'temp_max': 232.66, 'pressure': 1054, 'humidity': 95, 'sea_level': 1054, 'grnd_level': 1050}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 210, 'gust': 3.64}, 'clouds': {'all': 29}, 'dt': 1674234148, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# 71.9667 102.5 232.66 95 29 2.86 RU
# Processing Record 20 of Set 2 | faanui
# {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 299.99, 'feels_like': 302.21, 'temp_min': 299.99, 'temp_max': 299.99, 'pressure': 1014, 'humidity': 76, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 8.24, 'deg': 93, 'gust': 8.49}, 'rain': {'1h': 0.19}, 'clouds': {'all': 46}, 'dt': 1674234149, 'sys': {'country': 'PF', 'sunrise': 1674229756, 'sunset': 1674276384}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# -16.4833 -151.75 299.99 76 46 8.24 PF
# Processing Record 21 of Set 2 | burica
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 22 of Set 2 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 297.01, 'feels_like': 297.64, 'temp_min': 295.3, 'temp_max': 297.01, 'pressure': 1011, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 7.15, 'deg': 53, 'gust': 9.83}, 'rain': {'1h': 0.42}, 'clouds': {'all': 99}, 'dt': 1674234150, 'sys': {'type': 2, 'id': 2073060, 'country': 'AR', 'sunrise': 1674204578, 'sunset': 1674256340}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# -38.0023 -57.5575 297.01 84 99 7.15 AR
# Processing Record 23 of Set 2 | mugur-aksy
# {'coord': {'lon': 90.5, 'lat': 50.35}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 250.71, 'feels_like': 243.71, 'temp_min': 250.71, 'temp_max': 250.71, 'pressure': 1034, 'humidity': 89, 'sea_level': 1034, 'grnd_level': 800}, 'visibility': 10000, 'wind': {'speed': 3.24, 'deg': 265, 'gust': 2.94}, 'clouds': {'all': 83}, 'dt': 1674234150, 'sys': {'country': 'RU', 'sunrise': 1674265629, 'sunset': 1674297043}, 'timezone': 25200, 'id': 1498283, 'name': 'Mugur-Aksy', 'cod': 200}
# 50.35 90.5 250.71 89 83 3.24 RU
# Processing Record 24 of Set 2 | grindavik
# {'coord': {'lon': -22.4338, 'lat': 63.8424}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09n'}, {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 278.41, 'feels_like': 272.88, 'temp_min': 278.41, 'temp_max': 278.41, 'pressure': 980, 'humidity': 100}, 'visibility': 400, 'wind': {'speed': 10.8, 'deg': 170}, 'clouds': {'all': 100}, 'dt': 1674234151, 'sys': {'type': 1, 'id': 90, 'country': 'IS', 'sunrise': 1674211343, 'sunset': 1674232713}, 'timezone': 0, 'id': 3416888, 'name': 'Grindavik', 'cod': 200}
# 63.8424 -22.4338 278.41 100 100 10.8 IS
# Processing Record 25 of Set 2 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 247.36, 'feels_like': 240.36, 'temp_min': 247.36, 'temp_max': 247.36, 'pressure': 1039, 'humidity': 77, 'sea_level': 1039, 'grnd_level': 1033}, 'visibility': 10000, 'wind': {'speed': 13.05, 'deg': 182, 'gust': 23.54}, 'clouds': {'all': 70}, 'dt': 1674234151, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# 73.5069 80.5464 247.36 77 70 13.05 RU
# Processing Record 26 of Set 2 | taoudenni
# {'coord': {'lon': -3.9836, 'lat': 22.6783}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 298.57, 'feels_like': 297.51, 'temp_min': 298.57, 'temp_max': 298.57, 'pressure': 1014, 'humidity': 13, 'sea_level': 1014, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 5.39, 'deg': 52, 'gust': 6.25}, 'clouds': {'all': 0}, 'dt': 1674234152, 'sys': {'country': 'ML', 'sunrise': 1674197887, 'sunset': 1674237311}, 'timezone': 0, 'id': 2450173, 'name': 'Taoudenni', 'cod': 200}
# 22.6783 -3.9836 298.57 13 0 5.39 ML
# Processing Record 27 of Set 2 | nanortalik
# {'coord': {'lon': -45.2371, 'lat': 60.1432}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 266.99, 'feels_like': 259.99, 'temp_min': 266.99, 'temp_max': 266.99, 'pressure': 990, 'humidity': 67, 'sea_level': 990, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 10.53, 'deg': 311, 'gust': 11.35}, 'clouds': {'all': 46}, 'dt': 1674234153, 'sys': {'country': 'GL', 'sunrise': 1674214898, 'sunset': 1674240105}, 'timezone': -10800, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# 60.1432 -45.2371 266.99 67 46 10.53 GL
# Processing Record 28 of Set 2 | umm durman
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 2 | taree
# {'coord': {'lon': 152.4667, 'lat': -31.9}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 288.27, 'feels_like': 288.42, 'temp_min': 288.27, 'temp_max': 288.27, 'pressure': 1015, 'humidity': 99, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 1.31, 'deg': 246, 'gust': 2.36}, 'clouds': {'all': 80}, 'dt': 1674234153, 'sys': {'type': 2, 'id': 2080514, 'country': 'AU', 'sunrise': 1674241450, 'sunset': 1674291471}, 'timezone': 39600, 'id': 2147381, 'name': 'Taree', 'cod': 200}
# -31.9 152.4667 288.27 99 80 1.31 AU
# Processing Record 30 of Set 2 | provideniya
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 243.16, 'feels_like': 236.16, 'temp_min': 243.16, 'temp_max': 243.16, 'pressure': 1014, 'humidity': 94, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.61, 'deg': 327, 'gust': 2.93}, 'clouds': {'all': 12}, 'dt': 1674234154, 'sys': {'country': 'RU', 'sunrise': 1674334069, 'sunset': 1674355252}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# 64.3833 -173.3 243.16 94 12 2.61 RU
# Processing Record 31 of Set 2 | ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 252.16, 'feels_like': 245.16, 'temp_min': 252.16, 'temp_max': 252.16, 'pressure': 1002, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1674234155, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 1674223499, 'sunset': 1674234319}, 'timezone': -10800, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# 69.2167 -51.1 252.16 54 75 7.2 GL
# Processing Record 32 of Set 2 | bara
# {'coord': {'lon': 10.7288, 'lat': 10.3744}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 303.34, 'feels_like': 301.43, 'temp_min': 303.34, 'temp_max': 303.34, 'pressure': 1009, 'humidity': 14, 'sea_level': 1009, 'grnd_level': 972}, 'visibility': 10000, 'wind': {'speed': 3.39, 'deg': 83, 'gust': 3.48}, 'clouds': {'all': 23}, 'dt': 1674234155, 'sys': {'country': 'NG', 'sunrise': 1674193177, 'sunset': 1674234957}, 'timezone': 3600, 'id': 2347758, 'name': 'Bara', 'cod': 200}
# 10.3744 10.7288 303.34 14 23 3.39 NG
# ...
# 18.5007 102.4166 290.35 74 3 0.86 LA
# Processing Record 24 of Set 4 | beruwala
# {'coord': {'lon': 79.9828, 'lat': 6.4788}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.01, 'feels_like': 298.54, 'temp_min': 298.01, 'temp_max': 298.01, 'pressure': 1012, 'humidity': 76, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 160, 'gust': 4.33}, 'clouds': {'all': 100}, 'dt': 1674234325, 'sys': {'country': 'LK', 'sunrise': 1674176204, 'sunset': 1674218681}, 'timezone': 19800, 'id': 1249931, 'name': 'Beruwala', 'cod': 200}
# 6.4788 79.9828 298.01 76 100 1 LK
# Processing Record 25 of Set 4 | casian
# {'coord': {'lon': 119.7136, 'lat': 11.035}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.07, 'feels_like': 303.08, 'temp_min': 300.07, 'temp_max': 300.07, 'pressure': 1010, 'humidity': 84, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 11.59, 'deg': 67, 'gust': 15.23}, 'clouds': {'all': 76}, 'dt': 1674234326, 'sys': {'country': 'PH', 'sunrise': 1674253486, 'sunset': 1674295161}, 'timezone': 28800, 'id': 1718170, 'name': 'Casian', 'cod': 200}
# 11.035 119.7136 300.07 84 76 11.59 PH
# Processing Record 26 of Set 4 | kruisfontein
# {'coord': {'lon': 24.7314, 'lat': -34.0033}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 295.09, 'feels_like': 295.27, 'temp_min': 295.09, 'temp_max': 295.09, 'pressure': 1011, 'humidity': 74, 'sea_level': 1011, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 121, 'gust': 6.6}, 'clouds': {'all': 0}, 'dt': 1674234326, 'sys': {'country': 'ZA', 'sunrise': 1674185391, 'sunset': 1674236020}, 'timezone': 7200, 'id': 986717, 'name': 'Kruisfontein', 'cod': 200}
# -34.0033 24.7314 295.09 74 0 5.01 ZA
# Processing Record 27 of Set 4 | najran
# {'coord': {'lon': 44.1277, 'lat': 17.4924}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.83, 'feels_like': 288.42, 'temp_min': 289.83, 'temp_max': 289.83, 'pressure': 1019, 'humidity': 33, 'sea_level': 1019, 'grnd_level': 875}, 'visibility': 10000, 'wind': {'speed': 1.91, 'deg': 78, 'gust': 1.93}, 'clouds': {'all': 0}, 'dt': 1674234263, 'sys': {'country': 'SA', 'sunrise': 1674185825, 'sunset': 1674226274}, 'timezone': 10800, 'id': 103630, 'name': 'Najrān', 'cod': 200}
# 17.4924 44.1277 289.83 33 0 1.91 SA
# Processing Record 28 of Set 4 | laguna
# {'coord': {'lon': -121.4238, 'lat': 38.421}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 278.14, 'feels_like': 274.66, 'temp_min': 276.29, 'temp_max': 281.49, 'pressure': 1026, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 350}, 'clouds': {'all': 0}, 'dt': 1674234296, 'sys': {'type': 2, 'id': 2002655, 'country': 'US', 'sunrise': 1674227961, 'sunset': 1674263620}, 'timezone': -28800, 'id': 5364271, 'name': 'Laguna', 'cod': 200}
# 38.421 -121.4238 281.49 68 0 4.63 US
# Processing Record 29 of Set 4 | hammerfest
# {'coord': {'lon': 23.6821, 'lat': 70.6634}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.4, 'feels_like': 270.34, 'temp_min': 276.4, 'temp_max': 276.4, 'pressure': 1004, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 240, 'gust': 15.43}, 'clouds': {'all': 75}, 'dt': 1674234327, 'sys': {'type': 1, 'id': 1632, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 779683, 'name': 'Hammerfest', 'cod': 200}
# 70.6634 23.6821 276.4 65 75 10.29 NO
# Processing Record 30 of Set 4 | atar
# {'coord': {'lon': -13.0499, 'lat': 20.5169}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 299.38, 'feels_like': 299.38, 'temp_min': 299.38, 'temp_max': 299.38, 'pressure': 1013, 'humidity': 19, 'sea_level': 1013, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 3.06, 'deg': 288, 'gust': 2.59}, 'clouds': {'all': 0}, 'dt': 1674234328, 'sys': {'country': 'MR', 'sunrise': 1674199844, 'sunset': 1674239707}, 'timezone': 0, 'id': 2381334, 'name': 'Atar', 'cod': 200}
# 20.5169 -13.0499 299.38 19 0 3.06 MR
# Processing Record 31 of Set 4 | koulamoutou
# {'coord': {'lon': 12.4736, 'lat': -1.1303}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 297.37, 'feels_like': 298.12, 'temp_min': 297.37, 'temp_max': 297.37, 'pressure': 1009, 'humidity': 87, 'sea_level': 1009, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 1.52, 'deg': 203, 'gust': 3.83}, 'rain': {'1h': 0.3}, 'clouds': {'all': 100}, 'dt': 1674234329, 'sys': {'country': 'GA', 'sunrise': 1674191736, 'sunset': 1674235560}, 'timezone': 3600, 'id': 2399959, 'name': 'Koulamoutou', 'cod': 200}
# -1.1303 12.4736 297.37 87 100 1.52 GA
# Processing Record 32 of Set 4 | traralgon
# {'coord': {'lon': 146.5333, 'lat': -38.1833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 284, 'feels_like': 283.7, 'temp_min': 284, 'temp_max': 284, 'pressure': 1016, 'humidity': 98, 'sea_level': 1016, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 0.97, 'deg': 92, 'gust': 1.9}, 'clouds': {'all': 69}, 'dt': 1674234329, 'sys': {'country': 'AU', 'sunrise': 1674241998, 'sunset': 1674293773}, 'timezone': 39600, 'id': 2146108, 'name': 'Traralgon', 'cod': 200}
# -38.1833 146.5333 284 98 69 0.97 AU
# Processing Record 33 of Set 4 | aflu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 34 of Set 4 | karauzyak
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 4 | champerico
# {'coord': {'lon': -91.9167, 'lat': 14.3}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 305.45, 'feels_like': 310.93, 'temp_min': 305.45, 'temp_max': 305.45, 'pressure': 1014, 'humidity': 60, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 3.01, 'deg': 273, 'gust': 2.8}, 'clouds': {'all': 45}, 'dt': 1674234331, 'sys': {'type': 1, 'id': 7068, 'country': 'GT', 'sunrise': 1674218174, 'sunset': 1674259240}, 'timezone': -21600, 'id': 3598787, 'name': 'Champerico', 'cod': 200}
# 14.3 -91.9167 305.45 60 45 3.01 GT
# Processing Record 36 of Set 4 | pangnirtung
# {'coord': {'lon': -65.7125, 'lat': 66.1451}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 245.99, 'feels_like': 239.46, 'temp_min': 245.99, 'temp_max': 245.99, 'pressure': 1011, 'humidity': 98, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 2204, 'wind': {'speed': 1.84, 'deg': 48, 'gust': 1.74}, 'clouds': {'all': 100}, 'dt': 1674234102, 'sys': {'country': 'CA', 'sunrise': 1674223375, 'sunset': 1674241459}, 'timezone': -18000, 'id': 6096551, 'name': 'Pangnirtung', 'cod': 200}
# 66.1451 -65.7125 245.99 98 100 1.84 CA
# Processing Record 37 of Set 4 | tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 38 of Set 4 | umm lajj
# {'coord': {'lon': 37.2685, 'lat': 25.0213}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.43, 'feels_like': 296.2, 'temp_min': 296.43, 'temp_max': 296.43, 'pressure': 1015, 'humidity': 53, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.73, 'deg': 322, 'gust': 1.96}, 'clouds': {'all': 76}, 'dt': 1674234332, 'sys': {'country': 'SA', 'sunrise': 1674188233, 'sunset': 1674227159}, 'timezone': 10800, 'id': 100926, 'name': 'Umluj', 'cod': 200}
# 25.0213 37.2685 296.43 53 76 1.73 SA
# Processing Record 39 of Set 4 | wairoa
# {'coord': {'lon': 177.3667, 'lat': -39.0333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 287.34, 'feels_like': 287.24, 'temp_min': 287.34, 'temp_max': 287.34, 'pressure': 1002, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 23, 'gust': 1.79}, 'clouds': {'all': 4}, 'dt': 1674234332, 'sys': {'type': 2, 'id': 2011018, 'country': 'NZ', 'sunrise': 1674234460, 'sunset': 1674286507}, 'timezone': 46800, 'id': 2206808, 'name': 'Wairoa', 'cod': 200}
# -39.0333 177.3667 287.34 93 4 0.89 NZ
# Processing Record 40 of Set 4 | faya
# {'coord': {'lon': 42.4509, 'lat': 18.3851}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 286.44, 'feels_like': 285.7, 'temp_min': 286.44, 'temp_max': 286.44, 'pressure': 1018, 'humidity': 72, 'sea_level': 1018, 'grnd_level': 789}, 'visibility': 10000, 'wind': {'speed': 2.27, 'deg': 249, 'gust': 2.47}, 'clouds': {'all': 14}, 'dt': 1674234333, 'sys': {'type': 1, 'id': 7396, 'country': 'SA', 'sunrise': 1674186314, 'sunset': 1674226590}, 'timezone': 10800, 'id': 110690, 'name': 'Faya', 'cod': 200}
# 18.3851 42.4509 286.44 72 14 2.27 SA
# Processing Record 41 of Set 4 | bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 279.11, 'feels_like': 277.58, 'temp_min': 275.41, 'temp_max': 281.98, 'pressure': 1001, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 270, 'gust': 7.72}, 'clouds': {'all': 100}, 'dt': 1674234334, 'sys': {'type': 2, 'id': 2004826, 'country': 'US', 'sunrise': 1674216891, 'sunset': 1674251640}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# 41.3712 -73.414 281.98 77 100 2.06 US
# Processing Record 42 of Set 4 | port keats
# {'coord': {'lon': 129.55, 'lat': -14.25}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.58, 'feels_like': 304.36, 'temp_min': 300.58, 'temp_max': 300.58, 'pressure': 1005, 'humidity': 84, 'sea_level': 1005, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 254, 'gust': 4.12}, 'clouds': {'all': 100}, 'dt': 1674234314, 'sys': {'country': 'AU', 'sunrise': 1674248866, 'sunset': 1674295058}, 'timezone': 34200, 'id': 2063039, 'name': 'Port Keats', 'cod': 200}
# -14.25 129.55 300.58 84 100 2.57 AU
# Processing Record 43 of Set 4 | kita
# {'coord': {'lon': -9.4895, 'lat': 13.0349}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 308, 'feels_like': 305.32, 'temp_min': 308, 'temp_max': 308, 'pressure': 1009, 'humidity': 8, 'sea_level': 1009, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 1.34, 'deg': 322, 'gust': 0.91}, 'clouds': {'all': 5}, 'dt': 1674234334, 'sys': {'country': 'ML', 'sunrise': 1674198273, 'sunset': 1674239567}, 'timezone': 0, 'id': 2455216, 'name': 'Kita', 'cod': 200}
# 13.0349 -9.4895 308 8 5 1.34 ML
# Processing Record 44 of Set 4 | matara
# {'coord': {'lon': 80.5353, 'lat': 5.9485}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.49, 'feels_like': 296.99, 'temp_min': 296.49, 'temp_max': 296.49, 'pressure': 1013, 'humidity': 81, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.23, 'deg': 36, 'gust': 2.61}, 'clouds': {'all': 97}, 'dt': 1674234335, 'sys': {'country': 'LK', 'sunrise': 1674176025, 'sunset': 1674218595}, 'timezone': 19800, 'id': 1235846, 'name': 'Matara', 'cod': 200}
# 5.9485 80.5353 296.49 81 97 2.23 LK
# Processing Record 45 of Set 4 | kerema
# {'coord': {'lon': 145.7785, 'lat': -7.9631}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.52, 'feels_like': 299.33, 'temp_min': 298.52, 'temp_max': 298.52, 'pressure': 1007, 'humidity': 85, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 2.25, 'deg': 329, 'gust': 3.33}, 'rain': {'1h': 1.3}, 'clouds': {'all': 100}, 'dt': 1674234336, 'sys': {'country': 'PG', 'sunrise': 1674245549, 'sunset': 1674290584}, 'timezone': 36000, 'id': 2094144, 'name': 'Kerema', 'cod': 200}
# -7.9631 145.7785 298.52 85 100 2.25 PG
# Processing Record 46 of Set 4 | sinnai
# {'coord': {'lon': 9.2036, 'lat': 39.3042}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 278.26, 'feels_like': 274.12, 'temp_min': 277.87, 'temp_max': 280.65, 'pressure': 1008, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 320}, 'clouds': {'all': 20}, 'dt': 1674234336, 'sys': {'type': 2, 'id': 2080529, 'country': 'IT', 'sunrise': 1674196751, 'sunset': 1674232115}, 'timezone': 3600, 'id': 6539309, 'name': 'Sinnai', 'cod': 200}
# 39.3042 9.2036 280.65 81 20 6.17 IT
# Processing Record 47 of Set 4 | barcelos
# {'coord': {'lon': -8.6151, 'lat': 41.5388}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 287.45, 'feels_like': 287.21, 'temp_min': 286.86, 'temp_max': 287.55, 'pressure': 1023, 'humidity': 87, 'sea_level': 1023, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 3.55, 'deg': 324, 'gust': 6.14}, 'clouds': {'all': 30}, 'dt': 1674234337, 'sys': {'type': 2, 'id': 2021760, 'country': 'PT', 'sunrise': 1674201372, 'sunset': 1674236049}, 'timezone': 0, 'id': 2742416, 'name': 'Barcelos', 'cod': 200}
# 41.5388 -8.6151 287.55 87 30 3.55 PT
# Processing Record 48 of Set 4 | coahuayana
# {'coord': {'lon': -103.6833, 'lat': 18.7333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.31, 'feels_like': 302.28, 'temp_min': 301.31, 'temp_max': 301.31, 'pressure': 1017, 'humidity': 55, 'sea_level': 1017, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.18, 'deg': 277, 'gust': 0.91}, 'clouds': {'all': 92}, 'dt': 1674234337, 'sys': {'country': 'MX', 'sunrise': 1674221419, 'sunset': 1674261644}, 'timezone': -21600, 'id': 4013679, 'name': 'Coahuayana Viejo', 'cod': 200}
# 18.7333 -103.6833 301.31 55 92 1.18 MX
# Processing Record 49 of Set 4 | bolobo
# {'coord': {'lon': 16.2333, 'lat': -2.1667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 298.22, 'feels_like': 298.79, 'temp_min': 298.22, 'temp_max': 298.22, 'pressure': 1008, 'humidity': 77, 'sea_level': 1008, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 2.76, 'deg': 255, 'gust': 6.92}, 'rain': {'1h': 0.36}, 'clouds': {'all': 99}, 'dt': 1674234338, 'sys': {'country': 'CD', 'sunrise': 1674190742, 'sunset': 1674234750}, 'timezone': 3600, 'id': 2316748, 'name': 'Bolobo', 'cod': 200}
# -2.1667 16.2333 298.22 77 99 2.76 CD
# Processing Record 50 of Set 4 | hargeysa
# {'coord': {'lon': 44.065, 'lat': 9.56}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 289.49, 'feels_like': 289.4, 'temp_min': 289.49, 'temp_max': 289.49, 'pressure': 1018, 'humidity': 85, 'sea_level': 1018, 'grnd_level': 879}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 14, 'gust': 6.83}, 'clouds': {'all': 24}, 'dt': 1674234339, 'sys': {'country': 'SO', 'sunrise': 1674185102, 'sunset': 1674227027}, 'timezone': 10800, 'id': 57289, 'name': 'Hargeisa', 'cod': 200}
# 9.56 44.065 289.49 85 24 5.7 SO

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
data_file = "weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(data_file)
